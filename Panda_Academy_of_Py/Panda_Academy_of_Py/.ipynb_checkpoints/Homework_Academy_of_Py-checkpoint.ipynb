# %%
import pandas as pd
student_csv_pd = File =("../Resources/students_complete.csv")
student_data =pd.read_csv(student_csv_pd)

school_csv_pd= File =("../Resources/schools_complete.csv")
school_data= pd.read_csv(school_csv_pd)

# %%
### Create Bins and create new columns with Pass/Fail
reading_bins=[0,69,100]
math_bins=[0,69,100]
overall_bins=[0,69,100]

#Labels
group_names=["Fail","Pass"]
Pass_name=[0,1]

# %%
###### Pass / Fail Module  ########

#Reading Pass/Fail and Pass Count
student_data["Reading Pass/Fail"]=pd.cut(student_data["reading_score"],reading_bins,labels=group_names)
student_data["Reading Pass Count"]=pd.cut(student_data["reading_score"],reading_bins,labels=Pass_name)
student_data["Reading Pass Count"]=student_data["Reading Pass Count"].astype('float64')


##Math Pass/Fail and Pass Count
student_data["Math Pass/Fail"]=pd.cut(student_data["math_score"],math_bins,labels=group_names)
student_data["Math Pass Count"]=pd.cut(student_data["math_score"],math_bins,labels=Pass_name)
student_data["Math Pass Count"]=student_data["Math Pass Count"].astype('float64')

####################################
#student_data.columns

# %%
###DISTRICT SUMMARY###
#Answer metrics with no Frame
total_schools=school_data["School ID"].count()
total_students=student_data["Student ID"].count()
total_budget=school_data["budget"].sum()
per_student_budget=total_schools/total_budget
school_data.head()
# Out:
#    School ID            school_name      type  size   budget
# 0          0      Huang High School  District  2917  1910635
# 1          1   Figueroa High School  District  2949  1884411
# 2          2    Shelton High School   Charter  1761  1056600
# 3          3  Hernandez High School  District  4635  3022020
# 4          4    Griffin High School   Charter  1468   917500

# %%
### Merge School and Student data    ######
data_merged=pd.merge(student_data,school_data,how="left", on=["school_name","school_name"])

#data_merged.columns

# %%
### District Counters
Student_counter=data_merged["size"]/data_merged["size"]
data_merged['Students']=Student_counter


Budget_per_student=data_merged["budget"]/data_merged["size"]
data_merged['Budget divided by student']=Budget_per_student

data_merged.head()
# Out:
#    Student ID       student_name gender grade        school_name  \
# 0           0       Paul Bradley      M   9th  Huang High School
# 1           1       Victor Smith      M  12th  Huang High School
# 2           2    Kevin Rodriguez      M  12th  Huang High School
# 3           3  Dr. Richard Scott      M  12th  Huang High School
# 4           4         Bonnie Ray      F   9th  Huang High School
#
#    reading_score  math_score Reading Pass/Fail  Reading Pass Count  \
# 0             66          79              Fail                 0.0
# 1             94          61              Pass                 1.0
# 2             90          60              Pass                 1.0
# 3             67          58              Fail                 0.0
# 4             97          84              Pass                 1.0
#
#   Math Pass/Fail  Math Pass Count  School ID      type  size   budget  \
# 0           Pass              1.0          0  District  2917  1910635
# 1           Fail              0.0          0  District  2917  1910635
# 2           Fail              0.0          0  District  2917  1910635
# 3           Fail              0.0          0  District  2917  1910635
# 4           Pass              1.0          0  District  2917  1910635
#
#    Students  Budget divided by student
# 0       1.0                      655.0
# 1       1.0                      655.0
# 2       1.0                      655.0
# 3       1.0                      655.0
# 4       1.0                      655.0

# %%
#All Schools(tot)SCORE:Total Math,Reading with TOTAL avg Math and reading

#Total Math Scores
total_math_scores=student_data["math_score"].sum()
tot_avg_math_score=total_math_scores/total_students
student_data['Tot_Avg_Math']=tot_avg_math_score

#Total Reading Scores
total_read_scores=student_data["reading_score"].sum()
tot_avg_read_score=total_read_scores/total_students
student_data['Tot_Avg_Read']=tot_avg_read_score

#Percentage of students that passed math
total_math_pass=student_data.loc[student_data["Math Pass/Fail"]=="Pass","Math Pass/Fail"]
count_math_pass=total_math_pass.count()
tot_pct_math_pass=(count_math_pass/total_students)*100
student_data['Tot_Math_Pct_Pass']=tot_pct_math_pass

#Percentage of students that passed Reading
total_read_pass=student_data.loc[student_data["Reading Pass/Fail"]=="Pass","Reading Pass/Fail"]
count_read_pass=total_read_pass.count()
tot_pct_read_pass=(count_read_pass/total_students)*100
student_data['Tot_Pct_Pass']=tot_pct_read_pass

#Overall_pass
tot_pct_overeall_pass=(tot_pct_math_pass+ tot_pct_read_pass)/2
student_data['Tot_Overall_Pass_rate']=tot_pct_overeall_pass
#pct_overeall_pass

# %%
######################################################         ANSWER 1             ####################################

#Set up summary Dataframe to print metrics from above
frame_df=pd.DataFrame({"Total Schools":[total_schools],"Total Students":[total_students],"Total Budget":[total_budget],
                      "Average Math Score":[tot_avg_math_score],"Average Reading Score":[tot_avg_read_score],
                      "% Passing Math":[tot_pct_math_pass],"% Passing Reading":[tot_pct_read_pass],
                       "Overall_Pass_rate":[tot_pct_overeall_pass]})

frame_df["Total Students"] = frame_df["Total Students"].astype(float).map("{:,.0f}".format)
frame_df["Total Budget"] = frame_df["Total Budget"].astype(float).map("${:,.2f}".format)
frame_df

#Format Columns
###Need to look into later
########################################################################################################################
# Out:
#    Total Schools Total Students    Total Budget  Average Math Score  \
# 0             15         39,170  $24,649,428.00           78.985371
#
#    Average Reading Score  % Passing Math  % Passing Reading  Overall_Pass_rate
# 0               81.87784       74.980853          85.805463          80.393158

# %%
A2_Base=data_merged[["school_name","type","Students","Budget divided by student","reading_score","Reading Pass/Fail","Reading Pass Count", 
                     "math_score","Math Pass/Fail", "Math Pass Count","size", "budget","Student ID"]]
A2_Base.head()
# Out:
#          school_name      type  Students  Budget divided by student  \
# 0  Huang High School  District       1.0                      655.0
# 1  Huang High School  District       1.0                      655.0
# 2  Huang High School  District       1.0                      655.0
# 3  Huang High School  District       1.0                      655.0
# 4  Huang High School  District       1.0                      655.0
#
#    reading_score Reading Pass/Fail  Reading Pass Count  math_score  \
# 0             66              Fail                 0.0          79
# 1             94              Pass                 1.0          61
# 2             90              Pass                 1.0          60
# 3             67              Fail                 0.0          58
# 4             97              Pass                 1.0          84
#
#   Math Pass/Fail  Math Pass Count  size   budget  Student ID
# 0           Pass              1.0  2917  1910635           0
# 1           Fail              0.0  2917  1910635           1
# 2           Fail              0.0  2917  1910635           2
# 3           Fail              0.0  2917  1910635           3
# 4           Pass              1.0  2917  1910635           4

# %%
##Group data by school and type
A2_grp_school_type=A2_Base.groupby(["school_name","type"])
A2_grp_school_type_sum=A2_grp_school_type.sum()
A2_grp_school_type_sum.head()
# Out:
#                                Students  Budget divided by student  \
# school_name          type
# Bailey High School   District    4976.0                  3124928.0
# Cabrera High School  Charter     1858.0                  1081356.0
# Figueroa High School District    2949.0                  1884411.0
# Ford High School     District    2739.0                  1763916.0
# Griffin High School  Charter     1468.0                   917500.0
#
#                                reading_score  Reading Pass Count  math_score  \
# school_name          type
# Bailey High School   District         403225              4077.0      383393
# Cabrera High School  Charter          156027              1803.0      154329
# Figueroa High School District         239335              2381.0      226223
# Ford High School     District         221164              2172.0      211184
# Griffin High School  Charter          123043              1426.0      122360
#
#                                Math Pass Count      size       budget  \
# school_name          type
# Bailey High School   District           3318.0  24760576  15549641728
# Cabrera High School  Charter            1749.0   3452164   2009159448
# Figueroa High School District           1946.0   8696601   5557128039
# Ford High School     District           1871.0   7502121   4831365924
# Griffin High School  Charter            1371.0   2155024   1346890000
#
#                                Student ID
# school_name          type
# Bailey High School   District   101303896
# Cabrera High School  Charter     31477307
# Figueroa High School District    12949059
# Ford High School     District    99055935
# Griffin High School  Charter     19077394

# %%
####Average math & Reading at School level

##School Average math
sch_avg_math_score=A2_grp_school_type_sum["math_score"]/A2_grp_school_type_sum["Students"]
A2_grp_school_type_sum['School Average Math Score']=sch_avg_math_score

##School Average Reading
sch_avg_reading_score=A2_grp_school_type_sum["reading_score"]/A2_grp_school_type_sum["Students"]
A2_grp_school_type_sum['School Average Reading Score']=sch_avg_reading_score

A2_grp_school_type_sum.head()
# Out:
#                                Students  Budget divided by student  \
# school_name          type
# Bailey High School   District    4976.0                  3124928.0
# Cabrera High School  Charter     1858.0                  1081356.0
# Figueroa High School District    2949.0                  1884411.0
# Ford High School     District    2739.0                  1763916.0
# Griffin High School  Charter     1468.0                   917500.0
#
#                                reading_score  Reading Pass Count  math_score  \
# school_name          type
# Bailey High School   District         403225              4077.0      383393
# Cabrera High School  Charter          156027              1803.0      154329
# Figueroa High School District         239335              2381.0      226223
# Ford High School     District         221164              2172.0      211184
# Griffin High School  Charter          123043              1426.0      122360
#
#                                Math Pass Count      size       budget  \
# school_name          type
# Bailey High School   District           3318.0  24760576  15549641728
# Cabrera High School  Charter            1749.0   3452164   2009159448
# Figueroa High School District           1946.0   8696601   5557128039
# Ford High School     District           1871.0   7502121   4831365924
# Griffin High School  Charter            1371.0   2155024   1346890000
#
#                                Student ID  School Average Math Score  \
# school_name          type
# Bailey High School   District   101303896                  77.048432
# Cabrera High School  Charter     31477307                  83.061895
# Figueroa High School District    12949059                  76.711767
# Ford High School     District    99055935                  77.102592
# Griffin High School  Charter     19077394                  83.351499
#
#                                School Average Reading Score
# school_name          type
# Bailey High School   District                     81.033963
# Cabrera High School  Charter                      83.975780
# Figueroa High School District                     81.158020
# Ford High School     District                     80.746258
# Griffin High School  Charter                      83.816757

# %%
###Passing Rates

####  School Reading Pass rate
sch_reading_pass_rate=A2_grp_school_type_sum["Reading Pass Count"]/A2_grp_school_type_sum["Students"]
A2_grp_school_type_sum ['School Reading Pass Rate']=sch_reading_pass_rate*100

####  School Math Pass rate
sch_math_pass_rate=A2_grp_school_type_sum["Math Pass Count"]/A2_grp_school_type_sum["Students"]
A2_grp_school_type_sum ['School Math Pass Rate']=sch_math_pass_rate*100

###School Overall Pass Rate
sch_overall_pass_rate=(sch_reading_pass_rate+sch_math_pass_rate)/2
A2_grp_school_type_sum['School Overall Pass Rate']= sch_overall_pass_rate*100

# %%
###Budget per Student
sch_budget_per_student=A2_grp_school_type_sum["Budget divided by student"]/A2_grp_school_type_sum["Students"]
A2_grp_school_type_sum['School Budget Per Student']=sch_budget_per_student

# %%
A2_grp_school_type_sum=A2_grp_school_type_sum[["Students","Budget divided by student","School Budget Per Student",
                                              "School Average Math Score","School Average Reading Score",
                                              "School Math Pass Rate","School Reading Pass Rate","School Overall Pass Rate"]]
A2_grp_school_type_sum.head()
# Out:
#                                Students  Budget divided by student  \
# school_name          type
# Bailey High School   District    4976.0                  3124928.0
# Cabrera High School  Charter     1858.0                  1081356.0
# Figueroa High School District    2949.0                  1884411.0
# Ford High School     District    2739.0                  1763916.0
# Griffin High School  Charter     1468.0                   917500.0
#
#                                School Budget Per Student  \
# school_name          type
# Bailey High School   District                      628.0
# Cabrera High School  Charter                       582.0
# Figueroa High School District                      639.0
# Ford High School     District                      644.0
# Griffin High School  Charter                       625.0
#
#                                School Average Math Score  \
# school_name          type
# Bailey High School   District                  77.048432
# Cabrera High School  Charter                   83.061895
# Figueroa High School District                  76.711767
# Ford High School     District                  77.102592
# Griffin High School  Charter                   83.351499
#
#                                School Average Reading Score  \
# school_name          type
# Bailey High School   District                     81.033963
# Cabrera High School  Charter                      83.975780
# Figueroa High School District                     81.158020
# Ford High School     District                     80.746258
# Griffin High School  Charter                      83.816757
#
#                                School Math Pass Rate  \
# school_name          type
# Bailey High School   District              66.680064
# Cabrera High School  Charter               94.133477
# Figueroa High School District              65.988471
# Ford High School     District              68.309602
# Griffin High School  Charter               93.392371
#
#                                School Reading Pass Rate  \
# school_name          type
# Bailey High School   District                 81.933280
# Cabrera High School  Charter                  97.039828
# Figueroa High School District                 80.739234
# Ford High School     District                 79.299014
# Griffin High School  Charter                  97.138965
#
#                                School Overall Pass Rate
# school_name          type
# Bailey High School   District                 74.306672
# Cabrera High School  Charter                  95.586652
# Figueroa High School District                 73.363852
# Ford High School     District                 73.804308
# Griffin High School  Charter                  95.265668

# %%
###Format Results
A2_grp_school_type_sum["Students"]=A2_grp_school_type_sum["Students"].map("{:,.0f}".format)
A2_grp_school_type_sum["Budget divided by student"]=A2_grp_school_type_sum["Budget divided by student"].map("${:,.0f}".format)
A2_grp_school_type_sum["School Budget Per Student"]=A2_grp_school_type_sum["School Budget Per Student"].map("${:,.0f}".format)
A2_grp_school_type_sum["School Math Pass Rate"]=A2_grp_school_type_sum["School Math Pass Rate"].map("{:,.6f}".format)
A2_grp_school_type_sum["School Reading Pass Rate"]=A2_grp_school_type_sum["School Reading Pass Rate"].map("{:,.6f}".format)
A2_grp_school_type_sum["School Overall Pass Rate"]=A2_grp_school_type_sum["School Overall Pass Rate"].map("{:,.6f}".format)

# %%
A2_grp_school_type_sum=A2_grp_school_type_sum.rename(columns={"Students":"Total Students",
                                                              "Budget divided by student":"Total School Budget",
                                                             "School Budget Per Student":"Per Student Budget",
                                                             "School Average Math Score":"Average Math Score",
                                                             "School Average Reading Score":"Average Reading Score",
                                                             "School Math Pass Rate":"% Passing Math",
                                                             "School Reading Pass Rate":"% Passing Reading",
                                                             "School Overall Pass Rate":"% Overall Passing Rate"})
A2_grp_school_type_sum.head()
# Out:
#                               Total Students Total School Budget  \
# school_name          type
# Bailey High School   District          4,976          $3,124,928
# Cabrera High School  Charter           1,858          $1,081,356
# Figueroa High School District          2,949          $1,884,411
# Ford High School     District          2,739          $1,763,916
# Griffin High School  Charter           1,468            $917,500
#
#                               Per Student Budget  Average Math Score  \
# school_name          type
# Bailey High School   District               $628           77.048432
# Cabrera High School  Charter                $582           83.061895
# Figueroa High School District               $639           76.711767
# Ford High School     District               $644           77.102592
# Griffin High School  Charter                $625           83.351499
#
#                                Average Reading Score % Passing Math  \
# school_name          type
# Bailey High School   District              81.033963      66.680064
# Cabrera High School  Charter               83.975780      94.133477
# Figueroa High School District              81.158020      65.988471
# Ford High School     District              80.746258      68.309602
# Griffin High School  Charter               83.816757      93.392371
#
#                               % Passing Reading % Overall Passing Rate
# school_name          type
# Bailey High School   District         81.933280              74.306672
# Cabrera High School  Charter          97.039828              95.586652
# Figueroa High School District         80.739234              73.363852
# Ford High School     District         79.299014              73.804308
# Griffin High School  Charter          97.138965              95.265668

# %%
A3_Base=A2_grp_school_type_sum

# %%
##############################  Answer to TOP Schools by Overall Score##############################################
A4_Base_sort_HIGH=A3_Base.sort_values("% Overall Passing Rate",ascending=False)
A4_Base_sort_HIGH.head(5)
# Out:
#                             Total Students Total School Budget  \
# school_name         type
# Cabrera High School Charter          1,858          $1,081,356
# Thomas High School  Charter          1,635          $1,043,130
# Pena High School    Charter            962            $585,858
# Griffin High School Charter          1,468            $917,500
# Wilson High School  Charter          2,283          $1,319,574
#
#                             Per Student Budget  Average Math Score  \
# school_name         type
# Cabrera High School Charter               $582           83.061895
# Thomas High School  Charter               $638           83.418349
# Pena High School    Charter               $609           83.839917
# Griffin High School Charter               $625           83.351499
# Wilson High School  Charter               $578           83.274201
#
#                              Average Reading Score % Passing Math  \
# school_name         type
# Cabrera High School Charter              83.975780      94.133477
# Thomas High School  Charter              83.848930      93.272171
# Pena High School    Charter              84.044699      94.594595
# Griffin High School Charter              83.816757      93.392371
# Wilson High School  Charter              83.989488      93.867718
#
#                             % Passing Reading % Overall Passing Rate
# school_name         type
# Cabrera High School Charter         97.039828              95.586652
# Thomas High School  Charter         97.308869              95.290520
# Pena High School    Charter         95.945946              95.270270
# Griffin High School Charter         97.138965              95.265668
# Wilson High School  Charter         96.539641              95.203679

# %%
A4_Base=A3_Base

# %%
##############################  Answer to Bottom Schools by Overall Score##############################################
A5_Base_sort_LOW=A3_Base.sort_values("% Overall Passing Rate",ascending=True)
A5_Base_sort_LOW.head(5)
# Out:
#                                Total Students Total School Budget  \
# school_name           type
# Rodriguez High School District          3,999          $2,547,363
# Figueroa High School  District          2,949          $1,884,411
# Huang High School     District          2,917          $1,910,635
# Johnson High School   District          4,761          $3,094,650
# Ford High School      District          2,739          $1,763,916
#
#                                Per Student Budget  Average Math Score  \
# school_name           type
# Rodriguez High School District               $637           76.842711
# Figueroa High School  District               $639           76.711767
# Huang High School     District               $655           76.629414
# Johnson High School   District               $650           77.072464
# Ford High School      District               $644           77.102592
#
#                                 Average Reading Score % Passing Math  \
# school_name           type
# Rodriguez High School District              80.744686      66.366592
# Figueroa High School  District              81.158020      65.988471
# Huang High School     District              81.182722      65.683922
# Johnson High School   District              80.966394      66.057551
# Ford High School      District              80.746258      68.309602
#
#                                % Passing Reading % Overall Passing Rate
# school_name           type
# Rodriguez High School District         80.220055              73.293323
# Figueroa High School  District         80.739234              73.363852
# Huang High School     District         81.316421              73.500171
# Johnson High School   District         81.222432              73.639992
# Ford High School      District         79.299014              73.804308

# %%
#Create New Table for math_scores
Math_score_bygrade = student_data[["school_name","grade","math_score"]]

# %%
##### 9th grade avg (mean) scores
math9_score=Math_score_bygrade.loc[Math_score_bygrade["grade"]== "9th",["school_name","math_score"]]
math9_score1=math9_score.groupby(["school_name"])
math=math9_score1.mean()
math9=math.rename(columns={"math_score":"9th"})

##### 10th grade avg (mean) scores
math10_score=Math_score_bygrade.loc[Math_score_bygrade["grade"]== "10th",["school_name","math_score"]]
math10_score1=math10_score.groupby(["school_name"])
math10=math10_score1.mean()
math10=math10.rename(columns={"math_score":"10th"})

##### 11th grade avg (mean) scores
math11_score=Math_score_bygrade.loc[Math_score_bygrade["grade"]== "11th",["school_name","math_score"]]
math11_score1=math11_score.groupby(["school_name"])
math11=math11_score1.mean()
math11=math11.rename(columns={"math_score":"11th"})

##### 12th grade avg (mean) scores
math12_score=Math_score_bygrade.loc[Math_score_bygrade["grade"]== "12th",["school_name","math_score"]]
math12_score1=math12_score.groupby(["school_name"])
math12=math12_score1.mean()
math12=math12.rename(columns={"math_score":"12th"})

### Combine all grades
grades_9_10_combine=pd.merge(math9,math10,how="left",on=["school_name"])
grades_11_12_combine=pd.merge(math11,math12,how="left",on=["school_name"])
all_grades=pd.merge(grades_9_10_combine,grades_11_12_combine,how="left", on=["school_name"])
all_grades
# Out:
#                              9th       10th       11th       12th
# school_name
# Bailey High School     77.083676  76.996772  77.515588  76.492218
# Cabrera High School    83.094697  83.154506  82.765560  83.277487
# Figueroa High School   76.403037  76.539974  76.884344  77.151369
# Ford High School       77.361345  77.672316  76.918058  76.179963
# Griffin High School    82.044010  84.229064  83.842105  83.356164
# Hernandez High School  77.438495  77.337408  77.136029  77.186567
# Holden High School     83.787402  83.429825  85.000000  82.855422
# Huang High School      77.027251  75.908735  76.446602  77.225641
# Johnson High School    77.187857  76.691117  77.491653  76.863248
# Pena High School       83.625455  83.372000  84.328125  84.121547
# Rodriguez High School  76.859966  76.612500  76.395626  77.690748
# Shelton High School    83.420755  82.917411  83.383495  83.778976
# Thomas High School     83.590022  83.087886  83.498795  83.497041
# Wilson High School     83.085578  83.724422  83.195326  83.035794
# Wright High School     83.264706  84.010288  83.836782  83.644986

# %%
#Create New Table for Reading_scores
Reading_score_bygrade = student_data[["school_name","grade","reading_score"]]

# %%
##### 9th grade avg (mean) scores
Reading9_score=Reading_score_bygrade.loc[Reading_score_bygrade["grade"]== "9th",["school_name","reading_score"]]
Reading9_score1=Reading9_score.groupby(["school_name"])
Reading=Reading9_score1.mean()
Reading9=Reading.rename(columns={"reading_score":"9th"})

##### 10th grade avg (mean) scores
Reading10_score=Reading_score_bygrade.loc[Reading_score_bygrade["grade"]== "10th",["school_name","reading_score"]]
Reading10_score1=Reading10_score.groupby(["school_name"])
Reading10=Reading10_score1.mean()
Reading10=Reading10.rename(columns={"reading_score":"10th"})

##### 11th grade avg (mean) scores
Reading11_score=Reading_score_bygrade.loc[Reading_score_bygrade["grade"]== "11th",["school_name","reading_score"]]
Reading11_score1=Reading11_score.groupby(["school_name"])
Reading11=Reading11_score1.mean()
Reading11=Reading11.rename(columns={"reading_score":"11th"})

##### 12th grade avg (mean) scores
Reading12_score=Reading_score_bygrade.loc[Reading_score_bygrade["grade"]== "12th",["school_name","reading_score"]]
Reading12_score1=Reading12_score.groupby(["school_name"])
Reading12=Reading12_score1.mean()
Reading12=Reading12.rename(columns={"reading_score":"12th"})

### Combine all grades
Rgrades_9_10_combine=pd.merge(Reading9,Reading10,how="left",on=["school_name"])
Rgrades_11_12_combine=pd.merge(Reading11,Reading12,how="left",on=["school_name"])
Rall_grades=pd.merge(Rgrades_9_10_combine,Rgrades_11_12_combine,how="left", on=["school_name"])
Rall_grades
# Out:
#                              9th       10th       11th       12th
# school_name
# Bailey High School     81.303155  80.907183  80.945643  80.912451
# Cabrera High School    83.676136  84.253219  83.788382  84.287958
# Figueroa High School   81.198598  81.408912  80.640339  81.384863
# Ford High School       80.632653  81.262712  80.403642  80.662338
# Griffin High School    83.369193  83.706897  84.288089  84.013699
# Hernandez High School  80.866860  80.660147  81.396140  80.857143
# Holden High School     83.677165  83.324561  83.815534  84.698795
# Huang High School      81.290284  81.512386  81.417476  80.305983
# Johnson High School    81.260714  80.773431  80.616027  81.227564
# Pena High School       83.807273  83.612000  84.335938  84.591160
# Rodriguez High School  80.993127  80.629808  80.864811  80.376426
# Shelton High School    84.122642  83.441964  84.373786  82.781671
# Thomas High School     83.728850  84.254157  83.585542  83.831361
# Wilson High School     83.939778  84.021452  83.764608  84.317673
# Wright High School     83.833333  83.812757  84.156322  84.073171

# %%
A3_Base.columns
# Out:
# Index(['Total Students', 'Total School Budget', 'Per Student Budget',
#        'Average Math Score', 'Average Reading Score', '% Passing Math',
#        '% Passing Reading', '% Overall Passing Rate'],
#       dtype='object')

# %%
A3_Base.sort_values("Per Student Budget",ascending=False)
A3_Base.max()
# Out:
# Total Students                  962
# Total School Budget        $917,500
# Per Student Budget             $655
# Average Math Score          83.8399
# Average Reading Score       84.0447
# % Passing Math            94.594595
# % Passing Reading         97.308869
# % Overall Passing Rate    95.586652
# dtype: object

# %%
grp_school_spending.min()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-e66bab00799a> in <module>()
# ----> 1 grp_school_spending.min()
#
# NameError: name 'grp_school_spending' is not defined

# %%
##create and segregated data into spending bins

#Create Bins for school Spending
School_spending_amt_bins=[0, 585, 615, 645, 675]
School_spending_lab_bins=["<$585", "$585-615", "$615-645", "$645-675"]


#Put data into bins
grp_school_spending["Spending Buckets"]=pd.cut(grp_school_spending["Per Student Budget"],School_spending_amt_bins,
                                               labels=School_spending_lab_bins)
grp_school_spending

# %%
sort_grp=grp_school_spending.sort_values("Per Student Budget",ascending=True)
test=sort_grp
test

# %%
spending_less_585=test.loc[test["Spending Buckets"]== "<$585",["School Avg Math Score","School Avg Reading Score",
                                                               "School Avg Overall Score"]]
spending_less_585

# %%
rollup_585=spending_less_585.mean()
rollup_585
#Missing % passing reading, % passing math, and %

# %%
##Need to put above into Dataframe
